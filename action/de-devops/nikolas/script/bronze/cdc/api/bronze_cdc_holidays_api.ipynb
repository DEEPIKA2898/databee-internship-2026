# %% [markdown]
# # Bronze Layer: Holidays API (Simple Overwrite)
#
# **Pattern**: Overwrite (Full Load)
# **Source**: External API
#
# This notebook fetches holiday data and overwrites the bronze table. Simplified for Free Edition.

# %%
import requests
import pandas as pd
from pyspark.sql.functions import current_timestamp

print("🌐 Fetching holidays from API...")
url = "https://date.nager.at/api/v3/PublicHolidays/2024/US"
response = requests.get(url)
data = response.json()

df_pd = pd.DataFrame(data)
df = spark.createDataFrame(df_pd).withColumn("ingestion_timestamp", current_timestamp())

print("Saving to Bronze (Overwrite with Schema Evolution)...")
(
    df.write.format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable("workspace.bronze.holidays_api_cdc")
)
print("✓ Done.")
